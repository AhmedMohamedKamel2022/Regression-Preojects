# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

import warnings
warnings.simplefilter(action='ignore')
# %matplotlib inline

# %%
df = pd.read_csv('Ecommerce Customers.csv')
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0       835 Frank Tunnel\r\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\r\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\r\nCobbborough,...            Bisque
# 3    1414 David Throughway\r\nPort Jason, OH 22070-...       SaddleBrown
# 4    14023 Rodriguez Passage\r\nPort Jacobville, PR...  MediumAquaMarine
# ..                                                 ...               ...
# 495  4483 Jones Motorway Suite 872\r\nLake Jamiefur...               Tan
# 496  172 Owen Divide Suite 497\r\nWest Richard, CA ...     PaleVioletRed
# 497  0787 Andrews Ranch Apt. 633\r\nSouth Chadburgh...          Cornsilk
# 498  680 Jennifer Lodge Apt. 808\r\nBrendachester, ...              Teal
# 499  49791 Rachel Heights Apt. 898\r\nEast Drewboro...       DarkMagenta
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
#      Yearly Amount Spent
# 0             587.951054
# 1             392.204933
# 2             487.547505
# 3             581.852344
# 4             599.406092
# ..                   ...
# 495           573.847438
# 496           529.049004
# 497           551.620145
# 498           456.469510
# 499           497.778642
#
# [500 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
df.shape
# Out:
# (500, 8)

# %%
df.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
num_col = df._get_numeric_data()
num_col
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
#      Yearly Amount Spent
# 0             587.951054
# 1             392.204933
# 2             487.547505
# 3             581.852344
# 4             599.406092
# ..                   ...
# 495           573.847438
# 496           529.049004
# 497           551.620145
# 498           456.469510
# 499           497.778642
#
# [500 rows x 5 columns]

# %%
for col in num_col:
    sns.distplot(x=df[col], color='m')
    plt.show()

# %%
for col in num_col:
    if col != 'Yearly Amount Spent' :
        sns.scatterplot(x=df[col], y=df['Yearly Amount Spent'])
        plt.show()

# %%
for col in num_col:
    sns.boxplot(x=df[col])
    plt.show()

# %%
from datasist.structdata import detect_outliers
outliers = detect_outliers(df,0, num_col)

# %%
df.drop(outliers, inplace=True)

# %%
len(outliers)
# Out:
# 0

# %%
for col in num_col:
    sns.boxplot(x=df[col])
    sns.stripplot(x = df[col], color = 'red')
    plt.show()

# %%
for col in num_col:
    if col != 'Yearly Amount Spent' :
        sns.jointplot(x=df[col], y=df['Yearly Amount Spent'], color='g')
        plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Make Linear Regression Model

# %%
x = df[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']]
x
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
# [471 rows x 4 columns]

# %%
y = df['Yearly Amount Spent']
y
# Out:
# 0      587.951054
# 1      392.204933
# 2      487.547505
# 3      581.852344
# 4      599.406092
#           ...
# 495    573.847438
# 496    529.049004
# 497    551.620145
# 498    456.469510
# 499    497.778642
# Name: Yearly Amount Spent, Length: 471, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
scaler = StandardScaler()

scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
df.shape
# Out:
# (471, 8)

# %%
models = {
    "LR": LinearRegression(),
    "KNNR": KNeighborsRegressor(),
    "SVC" : SVR(),
    "DT" : DecisionTreeRegressor(),
    "RF" : RandomForestRegressor(),
    "XGB" : XGBRegressor()}

for name, model in models.items():
    print(f'Using model: {name}')
    model.fit(x_train, y_train)
    print(f'Training Score: {model.score(x_train, y_train)}')
    y_pred = model.predict(x_test)
    print(f'Test Score: {r2_score(y_test, y_pred)}')  
    print('-'*30)
# Out:
# Using model: LR
# Training Score: 0.9776618371796191
# Test Score: 0.9802320678633051
# ------------------------------
# Using model: KNNR
# Training Score: 0.9394063407773257
# Test Score: 0.9023677516477644
# ------------------------------
# Using model: SVC
# Training Score: 0.48819209526528917
# Test Score: 0.44724727546624954
# ------------------------------
# Using model: DT
# Training Score: 1.0
# Test Score: 0.8846147345327071
# ------------------------------
# Using model: RF
# Training Score: 0.9908370540883905
# Test Score: 0.9446277736974155
# ------------------------------
# Using model: XGB
# Training Score: 0.9999865061991629
# Test Score: 0.9383757592743656
# ------------------------------
